# %% [markdown]
# # Matplotlib Introductions
#
# - Matplotlib - Introduction,plot(),Controlling Line Properties,Working with Multiple Figures,Histograms

# %%
import numpy as np
import pandas as pd
import matplotlib.pyplot as plt

# %%
a = np.random.randint(1,200,150).reshape(50,3)
df = pd.DataFrame(a,columns=list("ABC"))

# %%
df.head()
# Out:
#      A    B    C
# 0  122  106  145
# 1   40   41  139
# 2   40   69   53
# 3  163  104  178
# 4   93  155   65

# %%
df.head(2)
# Out:
#      A    B    C
# 0  122  106  145
# 1   40   41  139

# %% [markdown]
# ## Line plot

# %%
plt.plot([0,1,2],[10,20,-2])

# %%
plt.plot(range(50),df.A)

# %%
df.A.head(10)
# Out:
# 0    122
# 1     40
# 2     40
# 3    163
# 4     93
# 5     84
# 6     86
# 7     88
# 8    173
# 9     86
# Name: A, dtype: int32

# %%
plt.figure(figsize=(16,4))
plt.plot(df.index,df.A)
plt.show()

# %%
plt.figure(figsize=(16,4))
plt.plot(df.index,df.A,color="r") # color= r,b,g,m,c,k, #<upto 65535>
plt.show()

# %%
plt.figure(figsize=(16,4))
plt.plot(df.index,df.A,color="#378455") # color= r,b,g,m,c,k, #<upto 65535>
plt.show()

# %%
plt.figure(figsize=(16,4))
plt.plot(df.index,df.A,"--r") # color= r,b,g,m,c,k, #<upto 65535>
plt.show()

# %%
plt.figure(figsize=(16,4))
plt.plot(df.index,df.A,"o-r") # color= r,b,g,m,c,k, #<upto 65535>
plt.show()

# %% [markdown]
# ## Scatter Plot

# %%
plt.figure(figsize=(16,4))
plt.scatter(range(50),df.B)
plt.show()

# %%
plt.figure(figsize=(16,4))
plt.scatter(range(50),df.B,color="g")
plt.show()

# %%
plt.figure(figsize=(16,4))
plt.scatter(range(50),df.B,color="g",alpha=.1)
plt.show()

# %%
plt.figure(figsize=(16,4))
plt.scatter(range(50),df.B,color="g",alpha=.1,s=300)
plt.show()

# %%
plt.figure(figsize=(16,4))
for i in range(50):
    plt.scatter(i,df.B[i],color="g",alpha=.2,s=.07*np.pi*df.B[i]**2)
plt.show()

# %%
plt.figure(figsize=(16,4))
for i in range(50):
    plt.scatter(i,df.B[i],alpha=.2,s=.02*np.pi*df.B[i]**2)
plt.show()

# %%
plt.figure(figsize=(16,4))
for i in range(50):
    if df.B[i]>150:
        plt.scatter(i,df.B[i],color="g",alpha=.4,s=.02*np.pi*df.B[i]**2,marker="*")
    else:
        plt.scatter(i,df.B[i],color="r",alpha=.1,s=.02*np.pi*df.B[i]**2)
plt.show()

# %%
plt.figure(figsize=(16,4))
for i in range(50):
    if df.B[i]>150:
        plt.scatter(i,df.B[i],color="g",alpha=.4,s=.02*np.pi*df.B[i]**2,marker="*")
    else:
        plt.scatter(i,df.B[i],color="r",alpha=.1,s=.02*np.pi*df.B[i]**2,marker="^")
plt.show()

# %%
plt.figure(figsize=(16,4))
for i in range(50):
    if df.B[i]>150:
        plt.scatter(i,df.B[i],color="g",alpha=.4,s=.02*np.pi*df.B[i]**2,marker="*")
        plt.text(i,df.B[i],df.B[i])
    else:
        plt.scatter(i,df.B[i],color="r",alpha=.1,s=.02*np.pi*df.B[i]**2,marker="^")

plt.show()

# %% [markdown]
# ## Saving Figure

# %%
plt.figure(figsize=(16,4))
for i in range(50):
    if df.B[i]>150:
        plt.scatter(i,df.B[i],color="g",alpha=.4,s=.02*np.pi*df.B[i]**2,marker="*")
        plt.text(i,df.B[i],df.B[i])
    else:
        plt.scatter(i,df.B[i],color="r",alpha=.1,s=.02*np.pi*df.B[i]**2,marker="^")
plt.savefig("star_preformer.png")
plt.show()

# %% [markdown]
# ## Bar Plot

# %%
plt.figure(figsize=(16,4))
for i in range(50):
    plt.bar(i,df.C[i])
    plt.text(i,df.C[i]+1,df.C[i])
plt.show()

# %% [markdown]
# ### Pandas default plots

# %%
a = np.random.randint(1,50,30).reshape(10,3)
df1 = pd.DataFrame(a,columns=list("ABC"))

# %%
df1.plot(kind="bar",figsize=(16,4))
plt.show()

# %%
df1.plot(kind="kde",figsize=(16,4))
plt.show()

# %%
df1.plot(kind="line",figsize=(16,4))
plt.show()

# %%
plt.figure(figsize=(16,4))
plt.plot(range(10),df1.A)
plt.show()
plt.plot(range(10),df1.B)
plt.plot(range(10),df1.C)
plt.show()

# %%
plt.figure(figsize=(16,4))
plt.plot(range(10),df1.A,"r")
plt.bar(range(10),df1.A)
plt.show()

# %%
plt.figure(figsize=(16,4))
plt.bar(range(50),df.C)
plt.show()

# %% [markdown]
# ## Controlling labels and ticks of graphs

# %%
plt.figure(figsize=(16,4))
plt.bar(range(50),df.C)
plt.xticks(range(50))
plt.yticks(range(0,200,10))
plt.xlabel("X-axis")
plt.ylabel("Y-axis")
plt.title("Bar-Graph")
plt.show()

# %%
plt.figure(figsize=(16,4))
plt.bar(range(50),df.C)
plt.xticks(range(50),rotation=90)
plt.yticks(range(0,200,10))
plt.xlabel("X-axis")
plt.ylabel("Y-axis")
plt.title("Bar-Graph")
plt.show()

# %%
plt.figure(figsize=(16,4))
plt.bar(range(50),df.C)
plt.xticks(range(50),rotation=90)
plt.yticks(range(0,200,10))
plt.xlabel("X-axis")
plt.ylabel("Y-axis")
plt.title("Bar-Graph")
plt.axis("off")
plt.show()

# %% [markdown]
# ## Histogram Plot

# %%
d = np.random.randint(1,7,1000)
plt.hist(d)
plt.show()

# %%
d = np.random.randint(1,100,500)
plt.hist(d)
plt.show()

# %%
plt.hist(d,bins=10,rwidth=.9)
plt.xticks(range(0,100,5))
plt.show()

# %% [markdown]
# ## Sub plotting

# %%
d = np.random.randint(1,100,40).reshape(10,4)
df = pd.DataFrame(d,columns=list("ABCD"))
df
# Out:
#     A   B   C   D
# 0   9  42   6  23
# 1  84  25  55  25
# 2  63  99  80  28
# 3  40  49  93  91
# 4  43  70   9  82
# 5  78  29  58  78
# 6  89  68  70  53
# 7  36  94  21   7
# 8  44  52  70  15
# 9  48  85  62  48

# %%
plt.subplot(2,2,1)
plt.plot(range(10),df.A)
plt.subplot(2,2,2)
plt.scatter(range(10),df.B)
plt.subplot(2,2,3)
plt.bar(range(10),df.C)
plt.subplot(224)
plt.barh(range(10),df.D)
# Out:
# <BarContainer object of 10 artists>

# %%
f,a = plt.subplots(2,2)
a[0][0].plot(range(10),df.A)
a[0][1].scatter(range(10),df.B)
a[1][0].bar(range(10),df.C)
a[1][1].barh(range(10),df.D)
# Out:
# <BarContainer object of 10 artists>
